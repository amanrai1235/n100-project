# %%
print("Day 42 Started")
# Out:
# Day 42 Started

# %%
import requests

requests.get(
    "http://127.0.0.1:8000/api/v1/companies"
).status_code
# Out:
# 200

# %%
requests.get(
    "http://127.0.0.1:8000/api/v1/sectors"
).json()
# Out:
# [{'sector': 'Unknown', 'company_count': '92'}]

# %%
requests.get(
    "http://127.0.0.1:8000/api/v1/screener",
    params={
        "min_roe":20
    }
).json()[:5]
# Out:
# [{'id': '16',
#   'company_id': 'TCS',
#   'compounded_sales_growth': 'TTM:            5%             ',
#   'compounded_profit_growth': 'TTM:                 8%',
#   'stock_price_cagr': '      1 Year:       16%',
#   'roe': 52,
#   'opm_percentage': 0},
#  {'id': '8',
#   'company_id': 'INFY',
#   'compounded_sales_growth': 'TTM:            3%',
#   'compounded_profit_growth': 'TTM:                 8%',
#   'stock_price_cagr': '       1 Year:       27%',
#   'roe': 32,
#   'opm_percentage': 0}]

# %%
print("DAY 42 COMPLETED")
# Out:
# DAY 42 COMPLETED
