# %%
import os
print(os.getcwd())
# Out:
# C:\Users\HP\OneDrive\Desktop\N100_Project\notebooks

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'day1_analysis.ipynb']

# %%
print(os.listdir("../data"))
# Out:
# ['processed', 'raw']

# %%
import os

print(os.listdir("../data/raw"))
# Out:
# []

# %%
import os

for root, dirs, files in os.walk(".."):
    for file in files:
        if file.endswith(".xlsx"):
            print(os.path.join(root, file))

# %%
import os

print(os.listdir("../data/raw"))
# Out:
# ['analysis.xlsx', 'balancesheet.xlsx', 'cashflow.xlsx', 'companies.xlsx', 'documents.xlsx', 'profitandloss.xlsx', 'prosandcons.xlsx']

# %%
import pandas as pd

companies = pd.read_excel("../data/raw/companies.xlsx")

companies.head()
# Out:
#   Mkt Fintech — Nifty 100  |  Companies  |  92 records  \
# 0                                                 id
# 1                                                ABB
# 2                                         ADANIENSOL
# 3                                           ADANIENT
# 4                                         ADANIGREEN
#
#                                           Unnamed: 1  \
# 0                                       company_logo
# 1   https://mkt.in/static/mkt-icons/nifty100/ABB.png
# 2  https://m.economictimes.com/thumb/msid-1173715...
# 3  https://mkt.in/static/mkt-icons/nifty100/ADANI...
# 4  https://mkt.in/static/mkt-icons/nifty100/ADANI...
#
#                    Unnamed: 2  \
# 0                company_name
# 1            Abbott India Ltd
# 2  Adani Energy Solutions Ltd
# 3       Adani Enterprises Ltd
# 4      Adani Green Energy Ltd
#
#                                           Unnamed: 3  \
# 0                                         chart_link
# 1  https://in.tradingview.com/chart/?symbol=NSE%3...
# 2  https://in.tradingview.com/chart/?symbol=NSE%3...
# 3  https://in.tradingview.com/chart/?symbol=ADANIENT
# 4  https://in.tradingview.com/chart/?symbol=NSE%3...
#
#                                           Unnamed: 4  \
# 0                                      about_company
# 1  Abbott India Ltd is one of the leading multina...
# 2  AESL, part of the Adani portfolio, is a multid...
# 3  Adani Enterprises Ltd is an Indian multination...
# 4  Adani Green Energy Limited, incorporated in 20...
#
#                               Unnamed: 5  \
# 0                                website
# 1              https://www.abbott.co.in/
# 2  https://www.adanienergysolutions.com/
# 3      https://www.adanienterprises.com/
# 4       http://www.adanigreenenergy.com/
#
#                                           Unnamed: 6  \
# 0                                        nse_profile
# 1  https://www.nseindia.com/get-quotes/equity?sym...
# 2  https://www.nseindia.com/get-quotes/equity?sym...
# 3  https://www.nseindia.com/get-quotes/equity?sym...
# 4  https://www.nseindia.com/get-quotes/equity?sym...
#
#                                           Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0                                        bse_profile  face_value  book_value
# 1  https://www.bseindia.com/stock-share-price/abb...          10        1657
# 2  https://www.bseindia.com/stock-share-price/ada...          10         175
# 3  https://www.bseindia.com/stock-share-price/ada...           1         363
# 4  https://www.bseindia.com/stock-share-price/ada...          10          67
#
#        Unnamed: 10     Unnamed: 11
# 0  roce_percentage  roe_percentage
# 1               46            34.9
# 2                9            8.59
# 3             11.6           13.64
# 4             96.5            14.7

# %%
companies.shape
# Out:
# (93, 12)

# %%
companies.columns
# Out:
# Index(['Mkt Fintech — Nifty 100  |  Companies  |  92 records', 'Unnamed: 1',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11'],
#       dtype='str')

# %%
companies.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 12 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Mkt Fintech — Nifty 100  |  Companies  |  92 records  93 non-null     str
#  1   Unnamed: 1                                            92 non-null     str
#  2   Unnamed: 2                                            93 non-null     str
#  3   Unnamed: 3                                            93 non-null     str
#  4   Unnamed: 4                                            93 non-null     str
#  5   Unnamed: 5                                            92 non-null     str
#  6   Unnamed: 6                                            92 non-null     str
#  7   Unnamed: 7                                            92 non-null     str
#  8   Unnamed: 8                                            92 non-null     object
#  9   Unnamed: 9                                            92 non-null     object
#  10  Unnamed: 10                                           92 non-null     object
#  11  Unnamed: 11                                           91 non-null     object
# dtypes: object(4), str(8)
# memory usage: 8.8+ KB

# %%
companies.isnull().sum()
# Out:
# Mkt Fintech — Nifty 100  |  Companies  |  92 records    0
# Unnamed: 1                                              1
# Unnamed: 2                                              0
# Unnamed: 3                                              0
# Unnamed: 4                                              0
# Unnamed: 5                                              1
# Unnamed: 6                                              1
# Unnamed: 7                                              1
# Unnamed: 8                                              1
# Unnamed: 9                                              1
# Unnamed: 10                                             1
# Unnamed: 11                                             2
# dtype: int64

# %%
companies.describe()
# Out:
#        Mkt Fintech — Nifty 100  |  Companies  |  92 records  \
# count                                                  93
# unique                                                 93
# top                                                    id
# freq                                                    1
#
#                                                Unnamed: 1    Unnamed: 2  \
# count                                                  92            93
# unique                                                 91            93
# top     https://mkt.in/static/mkt-icons/nifty100/HEROM...  company_name
# freq                                                    2             1
#
#                                                Unnamed: 3     Unnamed: 4  \
# count                                                  93             93
# unique                                                 55             93
# top     https://in.tradingview.com/chart/qGsydD2w/?sym...  about_company
# freq                                                   39              1
#
#                           Unnamed: 5   Unnamed: 6   Unnamed: 7  Unnamed: 8  \
# count                             92           92           92          92
# unique                            91           92           92           5
# top     https://www.bajajfinserv.in/  nse_profile  bse_profile          10
# freq                               2            1            1          31
#
#         Unnamed: 9  Unnamed: 10  Unnamed: 11
# count           92         92.0         91.0
# unique          85         85.0         86.0
# top            275         13.2         57.1
# freq             3          3.0          2.0

# %%
companies.describe(include="all")
# Out:
#        Mkt Fintech — Nifty 100  |  Companies  |  92 records  \
# count                                                  93
# unique                                                 93
# top                                                    id
# freq                                                    1
#
#                                                Unnamed: 1    Unnamed: 2  \
# count                                                  92            93
# unique                                                 91            93
# top     https://mkt.in/static/mkt-icons/nifty100/HEROM...  company_name
# freq                                                    2             1
#
#                                                Unnamed: 3     Unnamed: 4  \
# count                                                  93             93
# unique                                                 55             93
# top     https://in.tradingview.com/chart/qGsydD2w/?sym...  about_company
# freq                                                   39              1
#
#                           Unnamed: 5   Unnamed: 6   Unnamed: 7  Unnamed: 8  \
# count                             92           92           92          92
# unique                            91           92           92           5
# top     https://www.bajajfinserv.in/  nse_profile  bse_profile          10
# freq                               2            1            1          31
#
#         Unnamed: 9  Unnamed: 10  Unnamed: 11
# count           92         92.0         91.0
# unique          85         85.0         86.0
# top            275         13.2         57.1
# freq             3          3.0          2.0

# %%
analysis = pd.read_excel("../data/raw/analysis.xlsx")
balancesheet = pd.read_excel("../data/raw/balancesheet.xlsx")
cashflow = pd.read_excel("../data/raw/cashflow.xlsx")
profitandloss = pd.read_excel("../data/raw/profitandloss.xlsx")
documents = pd.read_excel("../data/raw/documents.xlsx")
prosandcons = pd.read_excel("../data/raw/prosandcons.xlsx")

# %%
datasets = {
    "companies": companies,
    "analysis": analysis,
    "balancesheet": balancesheet,
    "cashflow": cashflow,
    "profitandloss": profitandloss,
    "documents": documents,
    "prosandcons": prosandcons
}

for name, df in datasets.items():
    print(f"{name}: {df.shape}")
# Out:
# companies: (93, 12)
# analysis: (21, 6)
# balancesheet: (1313, 13)
# cashflow: (1188, 7)
# profitandloss: (1277, 15)
# documents: (1586, 4)
# prosandcons: (17, 4)

# %% [markdown]
# # Day 1 Summary
#
# ## Tasks Completed
#
# - Project structure created
# - Datasets loaded successfully
# - Data shape checked
# - Data types analyzed
# - Missing values checked
# - Basic exploratory analysis performed
#
# ## Dataset Summary
#
# | Dataset | Rows | Columns |
# |----------|------|----------|
# | Companies | 93 | 12 |
# | Analysis | 21 | 6 |
# | Balance Sheet | 1313 | 13 |
# | Cash Flow | 1188 | 7 |
# | Profit & Loss | 1277 | 15 |
# | Documents | 1586 | 4 |
# | Pros & Cons | 17 | 4 |
#
# ## Status
#
# Day 1 completed successfully.
