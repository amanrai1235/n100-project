# %% [markdown]
# # Day 28 - Final Documentation
#
# ## Objective
#
# Prepare project documentation, verify deliverables and finalize project submission.
#
# ## Outputs
#
# - acceptance_checklist.pdf
# - analyst_guide.pdf
# - final_submission_report.csv

# %%
import os
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect("../database/nifty100.db")

# %%
tables = pd.read_sql("""
SELECT name
FROM sqlite_master
WHERE type='table';
""", conn)

tables
# Out:
#             name
# 0      companies
# 1       analysis
# 2   balancesheet
# 3       cashflow
# 4  profitandloss
# 5      documents
# 6    prosandcons

# %%
reports = [
    "../reports/valuation_flags.csv",
    "../reports/valuation_summary.xlsx",
    "../reports/qa_summary.csv"
]

for report in reports:

    print(
        report,
        os.path.exists(report)
    )
# Out:
# ../reports/valuation_flags.csv True
# ../reports/valuation_summary.xlsx True
# ../reports/qa_summary.csv True

# %%
summary = pd.DataFrame({

    "Deliverable":[
        "Database",
        "Valuation",
        "QA",
        "Dashboard"
    ],

    "Status":[
        "Completed",
        "Completed",
        "Completed",
        "Completed"
    ]

})

summary
# Out:
#   Deliverable     Status
# 0    Database  Completed
# 1   Valuation  Completed
# 2          QA  Completed
# 3   Dashboard  Completed

# %%
summary.to_csv(
    "../reports/final_submission_report.csv",
    index=False
)

# %%
conn.close()
